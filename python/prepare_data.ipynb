# %%
"""
Read the source ACWF verification files and prepare a single JSON file that contains all the
relevant data and will be included in the application (as opposed to queried directly).

The source files are listed in the `labels.json` file and contain the following keys:

[
    BM_fit_data, completely_off, eos_data, failed_wfs, missing_outputs,
    num_atoms_in_sim_cell, script_version, set_name, stress_data, uuid_mapping
]

This current script will process these files into a single json with the format of
{
    metadata : {
        date : <date>, 
        methods: { <code> : {
            oxides : {filename: <x>, md5: <x>},
            unaries : {filename: <x>, md5: <x>},
            short_label : <x>
    }}}
    data : {
        <element> : { <crystalType (X2O, X2O3, X/BCC, ...)> : { <code> : {
            eos_data_per_atom: <x>,
            bm_fit_per_atom: <x>
        }}}
    }
}

where in `eos_data_per_atom` and `bm_fit_per_atom` the energy and volume are scaled to per atom.
If "per formula unit" is needed, just multiply accordingly.
"""

import requests
import os
from datetime import datetime
import hashlib
import json
import collections

def nested_dict():
    return collections.defaultdict(nested_dict)

def scale_bm_fit(bm_fit, num_atoms_in_cell):
    """Scale BM fit such that it is "per atom"
    """
    res = {
        "E0": bm_fit["E0"] / num_atoms_in_cell,
        "bulk_deriv": bm_fit["bulk_deriv"],
        "bulk_modulus_ev_ang3": bm_fit["bulk_modulus_ev_ang3"],
        "min_volume": bm_fit["min_volume"] / num_atoms_in_cell,
        "residuals": bm_fit["residuals"],
    }
    return res

def scale_eos_data(eos_data, num_atoms_in_cell):
    """Scale eos_data such that it is "per atom"
    """
    return [[x[0]/num_atoms_in_cell, x[1]/num_atoms_in_cell] for x in eos_data]

def process_json(source_json, current_data, code):
    """ Process the source json file into the specified format and populate current_data
    
    contains the data for a specific <code> and <oxides/unaries>
    
    The BM fit and EOS data is scaled to be "per atom".
    """
    
    # Process BM fit
    
    for elem_crystal in source_json["BM_fit_data"]:
        elem, crystal_type = elem_crystal.split("-")
        bm_fit = source_json["BM_fit_data"][elem_crystal]
        num_atoms_in_sim_cell = source_json["num_atoms_in_sim_cell"][elem_crystal]
        
        if bm_fit == None:
            print(f"  {code} BM_fit_data {elem_crystal} is None, skipping.")
            continue
        
        current_data[elem][crystal_type][code]["bm_fit_per_atom"] = scale_bm_fit(bm_fit, num_atoms_in_sim_cell)
    
    # Process EOS data
    if "eos_data" in source_json:
        for elem_crystal in source_json["eos_data"]:
            elem, crystal_type = elem_crystal.split("-")
            eos_data = source_json["eos_data"][elem_crystal]
            num_atoms_in_sim_cell = source_json["num_atoms_in_sim_cell"][elem_crystal]

            if eos_data == None:
                print(f"  {code} eos_data {elem_crystal} is None, skipping.")
                continue

            current_data[elem][crystal_type][code]["eos_data_per_atom"] = scale_eos_data(eos_data, num_atoms_in_sim_cell)

# %%
data_folder_url = "https://raw.githubusercontent.com/aiidateam/acwf-verification-scripts/main/acwf_paper_plots/code-data/"
labels_file = data_folder_url + "/labels.json"

r = requests.get(labels_file)
labels_json = r.json()

# %%
meta = {"date": datetime.today().strftime('%Y-%m-%d'), "methods": nested_dict()}
data = nested_dict()

methods = labels_json['references'] | labels_json['methods-main']

for method in methods:
    
    if "short_label" in methods[method]:
        meta["methods"][method]["short_label"] = methods[method]["short_label"]
    
    for crystal_type in ['unaries', 'oxides']:
        
        fname = methods[method][crystal_type]
        
        print(f'Loading {fname}')
    
        r = requests.get(data_folder_url + fname)
        md5 = hashlib.md5(r.content).hexdigest()
        meta["methods"][method][crystal_type]["filename"] = fname
        meta["methods"][method][crystal_type]["md5"] = md5

        process_json(r.json(), data, method)
# Out:
# Loading results-unaries-verification-PBE-v1-AE-average.json
# Loading results-oxides-verification-PBE-v1-AE-average.json
# Loading results-unaries-verification-PBE-v1-abinit-PseudoDojo-0.5b1-PBE-SR-standard-psp8.json
# Loading results-oxides-verification-PBE-v1-abinit-PseudoDojo-0.5b1-PBE-SR-standard-psp8.json
# Loading results-unaries-verification-PBE-v1-bigdft.json
#   BigDFT+... BM_fit_data B-X/SC is None, skipping.
#   BigDFT+... BM_fit_data C-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Ce-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Ce-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Ce-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Ce-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Co-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Co-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Co-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Co-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Cr-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Cr-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Cs-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Cu-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Dy-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Dy-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Dy-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Dy-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Er-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Er-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Er-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Er-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Eu-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Eu-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Eu-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Eu-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Fe-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Fe-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Fe-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Gd-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Gd-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Gd-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Gd-X/SC is None, skipping.
#   BigDFT+... BM_fit_data H-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data H-X/SC is None, skipping.
#   BigDFT+... BM_fit_data He-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data He-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Ho-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Ho-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Ho-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Ho-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Lu-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Lu-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Lu-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Lu-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Mn-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Mn-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data N-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data N-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Na-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Na-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Na-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Na-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Nb-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Nd-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Nd-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Nd-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Nd-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Ne-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Ne-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Ne-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Ne-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Ni-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Ni-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Ni-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Ni-X/SC is None, skipping.
#   BigDFT+... BM_fit_data O-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Pm-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Pm-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Pm-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Pm-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Pr-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Pr-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Pr-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Pr-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Re-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Re-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Sm-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Sm-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Sm-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Sm-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Tb-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Tb-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Tb-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Tb-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Tl-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Tl-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Tl-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Tl-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Tm-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Tm-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Tm-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Tm-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Yb-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Yb-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Yb-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Yb-X/SC is None, skipping.
#   BigDFT+... BM_fit_data Zn-X/BCC is None, skipping.
#   BigDFT+... BM_fit_data Zn-X/Diamond is None, skipping.
#   BigDFT+... BM_fit_data Zn-X/FCC is None, skipping.
#   BigDFT+... BM_fit_data Zn-X/SC is None, skipping.
#   BigDFT+... eos_data B-X/SC is None, skipping.
#   BigDFT+... eos_data C-X/SC is None, skipping.
#   BigDFT+... eos_data Ce-X/BCC is None, skipping.
#   BigDFT+... eos_data Ce-X/Diamond is None, skipping.
#   BigDFT+... eos_data Ce-X/FCC is None, skipping.
#   BigDFT+... eos_data Ce-X/SC is None, skipping.
#   BigDFT+... eos_data Co-X/BCC is None, skipping.
#   BigDFT+... eos_data Co-X/Diamond is None, skipping.
#   BigDFT+... eos_data Co-X/FCC is None, skipping.
#   BigDFT+... eos_data Co-X/SC is None, skipping.
#   BigDFT+... eos_data Cr-X/Diamond is None, skipping.
#   BigDFT+... eos_data Cr-X/FCC is None, skipping.
#   BigDFT+... eos_data Cs-X/Diamond is None, skipping.
#   BigDFT+... eos_data Cu-X/BCC is None, skipping.
#   BigDFT+... eos_data Dy-X/BCC is None, skipping.
#   BigDFT+... eos_data Dy-X/Diamond is None, skipping.
#   BigDFT+... eos_data Dy-X/FCC is None, skipping.
#   BigDFT+... eos_data Dy-X/SC is None, skipping.
#   BigDFT+... eos_data Er-X/BCC is None, skipping.
#   BigDFT+... eos_data Er-X/Diamond is None, skipping.
#   BigDFT+... eos_data Er-X/FCC is None, skipping.
#   BigDFT+... eos_data Er-X/SC is None, skipping.
#   BigDFT+... eos_data Eu-X/BCC is None, skipping.
#   BigDFT+... eos_data Eu-X/Diamond is None, skipping.
#   BigDFT+... eos_data Eu-X/FCC is None, skipping.
#   BigDFT+... eos_data Eu-X/SC is None, skipping.
#   BigDFT+... eos_data Fe-X/Diamond is None, skipping.
#   BigDFT+... eos_data Fe-X/FCC is None, skipping.
#   BigDFT+... eos_data Fe-X/SC is None, skipping.
#   BigDFT+... eos_data Gd-X/BCC is None, skipping.
#   BigDFT+... eos_data Gd-X/Diamond is None, skipping.
#   BigDFT+... eos_data Gd-X/FCC is None, skipping.
#   BigDFT+... eos_data Gd-X/SC is None, skipping.
#   BigDFT+... eos_data H-X/BCC is None, skipping.
#   BigDFT+... eos_data H-X/SC is None, skipping.
#   BigDFT+... eos_data He-X/BCC is None, skipping.
#   BigDFT+... eos_data He-X/Diamond is None, skipping.
#   BigDFT+... eos_data Ho-X/BCC is None, skipping.
#   BigDFT+... eos_data Ho-X/Diamond is None, skipping.
#   BigDFT+... eos_data Ho-X/FCC is None, skipping.
#   BigDFT+... eos_data Ho-X/SC is None, skipping.
#   BigDFT+... eos_data Lu-X/BCC is None, skipping.
#   BigDFT+... eos_data Lu-X/Diamond is None, skipping.
#   BigDFT+... eos_data Lu-X/FCC is None, skipping.
#   BigDFT+... eos_data Lu-X/SC is None, skipping.
#   BigDFT+... eos_data Mn-X/BCC is None, skipping.
#   BigDFT+... eos_data Mn-X/FCC is None, skipping.
#   BigDFT+... eos_data N-X/BCC is None, skipping.
#   BigDFT+... eos_data N-X/SC is None, skipping.
#   BigDFT+... eos_data Na-X/BCC is None, skipping.
#   BigDFT+... eos_data Na-X/Diamond is None, skipping.
#   BigDFT+... eos_data Na-X/FCC is None, skipping.
#   BigDFT+... eos_data Na-X/SC is None, skipping.
#   BigDFT+... eos_data Nb-X/Diamond is None, skipping.
#   BigDFT+... eos_data Nd-X/BCC is None, skipping.
#   BigDFT+... eos_data Nd-X/Diamond is None, skipping.
#   BigDFT+... eos_data Nd-X/FCC is None, skipping.
#   BigDFT+... eos_data Nd-X/SC is None, skipping.
#   BigDFT+... eos_data Ne-X/BCC is None, skipping.
#   BigDFT+... eos_data Ne-X/Diamond is None, skipping.
#   BigDFT+... eos_data Ne-X/FCC is None, skipping.
#   BigDFT+... eos_data Ne-X/SC is None, skipping.
#   BigDFT+... eos_data Ni-X/BCC is None, skipping.
#   BigDFT+... eos_data Ni-X/Diamond is None, skipping.
#   BigDFT+... eos_data Ni-X/FCC is None, skipping.
#   BigDFT+... eos_data Ni-X/SC is None, skipping.
#   BigDFT+... eos_data O-X/FCC is None, skipping.
#   BigDFT+... eos_data Pm-X/BCC is None, skipping.
#   BigDFT+... eos_data Pm-X/Diamond is None, skipping.
#   BigDFT+... eos_data Pm-X/FCC is None, skipping.
#   BigDFT+... eos_data Pm-X/SC is None, skipping.
#   BigDFT+... eos_data Pr-X/BCC is None, skipping.
#   BigDFT+... eos_data Pr-X/Diamond is None, skipping.
#   BigDFT+... eos_data Pr-X/FCC is None, skipping.
#   BigDFT+... eos_data Pr-X/SC is None, skipping.
#   BigDFT+... eos_data Re-X/BCC is None, skipping.
#   BigDFT+... eos_data Re-X/SC is None, skipping.
#   BigDFT+... eos_data Sm-X/BCC is None, skipping.
#   BigDFT+... eos_data Sm-X/Diamond is None, skipping.
#   BigDFT+... eos_data Sm-X/FCC is None, skipping.
#   BigDFT+... eos_data Sm-X/SC is None, skipping.
#   BigDFT+... eos_data Tb-X/BCC is None, skipping.
#   BigDFT+... eos_data Tb-X/Diamond is None, skipping.
#   BigDFT+... eos_data Tb-X/FCC is None, skipping.
#   BigDFT+... eos_data Tb-X/SC is None, skipping.
#   BigDFT+... eos_data Tl-X/BCC is None, skipping.
#   BigDFT+... eos_data Tl-X/Diamond is None, skipping.
#   BigDFT+... eos_data Tl-X/FCC is None, skipping.
#   BigDFT+... eos_data Tl-X/SC is None, skipping.
#   BigDFT+... eos_data Tm-X/BCC is None, skipping.
#   BigDFT+... eos_data Tm-X/Diamond is None, skipping.
#   BigDFT+... eos_data Tm-X/FCC is None, skipping.
#   BigDFT+... eos_data Tm-X/SC is None, skipping.
#   BigDFT+... eos_data Yb-X/BCC is None, skipping.
#   BigDFT+... eos_data Yb-X/Diamond is None, skipping.
#   BigDFT+... eos_data Yb-X/FCC is None, skipping.
#   BigDFT+... eos_data Yb-X/SC is None, skipping.
#   BigDFT+... eos_data Zn-X/BCC is None, skipping.
#   BigDFT+... eos_data Zn-X/Diamond is None, skipping.
#   BigDFT+... eos_data Zn-X/FCC is None, skipping.
#   BigDFT+... eos_data Zn-X/SC is None, skipping.
# Loading results-oxides-verification-PBE-v1-bigdft.json
#   BigDFT+... BM_fit_data Ag-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ag-XO is None, skipping.
#   BigDFT+... BM_fit_data Ag-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Al-X2O is None, skipping.
#   BigDFT+... BM_fit_data Al-XO is None, skipping.
#   BigDFT+... BM_fit_data Al-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ar-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ar-XO is None, skipping.
#   BigDFT+... BM_fit_data Ar-XO2 is None, skipping.
#   BigDFT+... BM_fit_data As-X2O is None, skipping.
#   BigDFT+... BM_fit_data As-XO is None, skipping.
#   BigDFT+... BM_fit_data As-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Au-X2O is None, skipping.
#   BigDFT+... BM_fit_data Au-XO is None, skipping.
#   BigDFT+... BM_fit_data Au-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Au-XO3 is None, skipping.
#   BigDFT+... BM_fit_data B-X2O is None, skipping.
#   BigDFT+... BM_fit_data B-XO is None, skipping.
#   BigDFT+... BM_fit_data B-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ba-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ba-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Ba-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Ba-XO is None, skipping.
#   BigDFT+... BM_fit_data Ba-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Be-X2O is None, skipping.
#   BigDFT+... BM_fit_data Be-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Be-XO is None, skipping.
#   BigDFT+... BM_fit_data Be-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Bi-X2O is None, skipping.
#   BigDFT+... BM_fit_data Bi-XO is None, skipping.
#   BigDFT+... BM_fit_data Bi-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Br-X2O is None, skipping.
#   BigDFT+... BM_fit_data Br-XO is None, skipping.
#   BigDFT+... BM_fit_data Br-XO2 is None, skipping.
#   BigDFT+... BM_fit_data C-X2O is None, skipping.
#   BigDFT+... BM_fit_data C-XO is None, skipping.
#   BigDFT+... BM_fit_data C-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ca-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ca-XO is None, skipping.
#   BigDFT+... BM_fit_data Ca-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Cd-X2O is None, skipping.
#   BigDFT+... BM_fit_data Cd-XO is None, skipping.
#   BigDFT+... BM_fit_data Cd-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ce-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ce-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Ce-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Ce-XO is None, skipping.
#   BigDFT+... BM_fit_data Ce-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ce-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Cl-X2O is None, skipping.
#   BigDFT+... BM_fit_data Cl-XO is None, skipping.
#   BigDFT+... BM_fit_data Cl-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Co-X2O is None, skipping.
#   BigDFT+... BM_fit_data Co-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Co-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Co-XO is None, skipping.
#   BigDFT+... BM_fit_data Co-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Co-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Cr-X2O is None, skipping.
#   BigDFT+... BM_fit_data Cr-XO is None, skipping.
#   BigDFT+... BM_fit_data Cr-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Cs-X2O is None, skipping.
#   BigDFT+... BM_fit_data Cs-XO is None, skipping.
#   BigDFT+... BM_fit_data Cs-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Cs-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Cu-X2O is None, skipping.
#   BigDFT+... BM_fit_data Cu-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Cu-XO is None, skipping.
#   BigDFT+... BM_fit_data Cu-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Dy-X2O is None, skipping.
#   BigDFT+... BM_fit_data Dy-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Dy-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Dy-XO is None, skipping.
#   BigDFT+... BM_fit_data Dy-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Dy-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Er-X2O is None, skipping.
#   BigDFT+... BM_fit_data Er-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Er-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Er-XO is None, skipping.
#   BigDFT+... BM_fit_data Er-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Er-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Eu-X2O is None, skipping.
#   BigDFT+... BM_fit_data Eu-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Eu-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Eu-XO is None, skipping.
#   BigDFT+... BM_fit_data Eu-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Eu-XO3 is None, skipping.
#   BigDFT+... BM_fit_data F-X2O is None, skipping.
#   BigDFT+... BM_fit_data F-XO is None, skipping.
#   BigDFT+... BM_fit_data F-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Fe-X2O is None, skipping.
#   BigDFT+... BM_fit_data Fe-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Fe-XO is None, skipping.
#   BigDFT+... BM_fit_data Fe-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ga-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ga-XO is None, skipping.
#   BigDFT+... BM_fit_data Ga-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Gd-X2O is None, skipping.
#   BigDFT+... BM_fit_data Gd-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Gd-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Gd-XO is None, skipping.
#   BigDFT+... BM_fit_data Gd-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Gd-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Ge-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ge-XO is None, skipping.
#   BigDFT+... BM_fit_data Ge-XO2 is None, skipping.
#   BigDFT+... BM_fit_data H-X2O is None, skipping.
#   BigDFT+... BM_fit_data H-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data H-XO is None, skipping.
#   BigDFT+... BM_fit_data H-XO2 is None, skipping.
#   BigDFT+... BM_fit_data He-X2O is None, skipping.
#   BigDFT+... BM_fit_data He-XO is None, skipping.
#   BigDFT+... BM_fit_data He-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Hf-X2O is None, skipping.
#   BigDFT+... BM_fit_data Hf-XO is None, skipping.
#   BigDFT+... BM_fit_data Hf-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Hg-X2O is None, skipping.
#   BigDFT+... BM_fit_data Hg-XO is None, skipping.
#   BigDFT+... BM_fit_data Hg-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ho-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ho-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Ho-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Ho-XO is None, skipping.
#   BigDFT+... BM_fit_data Ho-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ho-XO3 is None, skipping.
#   BigDFT+... BM_fit_data I-X2O is None, skipping.
#   BigDFT+... BM_fit_data I-XO is None, skipping.
#   BigDFT+... BM_fit_data I-XO2 is None, skipping.
#   BigDFT+... BM_fit_data I-XO3 is None, skipping.
#   BigDFT+... BM_fit_data In-X2O is None, skipping.
#   BigDFT+... BM_fit_data In-XO is None, skipping.
#   BigDFT+... BM_fit_data In-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ir-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ir-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Ir-XO is None, skipping.
#   BigDFT+... BM_fit_data Ir-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ir-XO3 is None, skipping.
#   BigDFT+... BM_fit_data K-X2O is None, skipping.
#   BigDFT+... BM_fit_data K-XO is None, skipping.
#   BigDFT+... BM_fit_data K-XO2 is None, skipping.
#   BigDFT+... BM_fit_data K-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Kr-X2O is None, skipping.
#   BigDFT+... BM_fit_data Kr-XO is None, skipping.
#   BigDFT+... BM_fit_data Kr-XO2 is None, skipping.
#   BigDFT+... BM_fit_data La-X2O is None, skipping.
#   BigDFT+... BM_fit_data La-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data La-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data La-XO is None, skipping.
#   BigDFT+... BM_fit_data La-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Li-X2O is None, skipping.
#   BigDFT+... BM_fit_data Li-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Li-XO is None, skipping.
#   BigDFT+... BM_fit_data Li-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Li-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Lu-X2O is None, skipping.
#   BigDFT+... BM_fit_data Lu-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Lu-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Lu-XO is None, skipping.
#   BigDFT+... BM_fit_data Lu-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Lu-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Mg-X2O is None, skipping.
#   BigDFT+... BM_fit_data Mg-XO is None, skipping.
#   BigDFT+... BM_fit_data Mg-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Mn-X2O is None, skipping.
#   BigDFT+... BM_fit_data Mn-XO is None, skipping.
#   BigDFT+... BM_fit_data Mn-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Mo-X2O is None, skipping.
#   BigDFT+... BM_fit_data Mo-XO is None, skipping.
#   BigDFT+... BM_fit_data Mo-XO2 is None, skipping.
#   BigDFT+... BM_fit_data N-X2O is None, skipping.
#   BigDFT+... BM_fit_data N-XO is None, skipping.
#   BigDFT+... BM_fit_data N-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Na-X2O is None, skipping.
#   BigDFT+... BM_fit_data Na-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Na-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Na-XO is None, skipping.
#   BigDFT+... BM_fit_data Na-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Na-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Nb-X2O is None, skipping.
#   BigDFT+... BM_fit_data Nb-XO is None, skipping.
#   BigDFT+... BM_fit_data Nb-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Nd-X2O is None, skipping.
#   BigDFT+... BM_fit_data Nd-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Nd-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Nd-XO is None, skipping.
#   BigDFT+... BM_fit_data Nd-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Nd-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Ne-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ne-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Ne-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Ne-XO is None, skipping.
#   BigDFT+... BM_fit_data Ne-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ni-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ni-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Ni-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Ni-XO is None, skipping.
#   BigDFT+... BM_fit_data Ni-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ni-XO3 is None, skipping.
#   BigDFT+... BM_fit_data O-X2O is None, skipping.
#   BigDFT+... BM_fit_data O-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data O-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data O-XO is None, skipping.
#   BigDFT+... BM_fit_data O-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Os-X2O is None, skipping.
#   BigDFT+... BM_fit_data Os-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Os-XO is None, skipping.
#   BigDFT+... BM_fit_data Os-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Os-XO3 is None, skipping.
#   BigDFT+... BM_fit_data P-X2O is None, skipping.
#   BigDFT+... BM_fit_data P-XO is None, skipping.
#   BigDFT+... BM_fit_data P-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Pb-X2O is None, skipping.
#   BigDFT+... BM_fit_data Pb-XO is None, skipping.
#   BigDFT+... BM_fit_data Pb-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Pd-X2O is None, skipping.
#   BigDFT+... BM_fit_data Pd-XO is None, skipping.
#   BigDFT+... BM_fit_data Pd-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Pm-X2O is None, skipping.
#   BigDFT+... BM_fit_data Pm-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Pm-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Pm-XO is None, skipping.
#   BigDFT+... BM_fit_data Pm-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Pm-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Po-X2O is None, skipping.
#   BigDFT+... BM_fit_data Po-XO is None, skipping.
#   BigDFT+... BM_fit_data Po-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Po-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Pr-X2O is None, skipping.
#   BigDFT+... BM_fit_data Pr-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Pr-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Pr-XO is None, skipping.
#   BigDFT+... BM_fit_data Pr-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Pr-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Pt-X2O is None, skipping.
#   BigDFT+... BM_fit_data Pt-XO is None, skipping.
#   BigDFT+... BM_fit_data Pt-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Pt-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Rb-X2O is None, skipping.
#   BigDFT+... BM_fit_data Rb-XO is None, skipping.
#   BigDFT+... BM_fit_data Rb-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Rb-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Re-X2O is None, skipping.
#   BigDFT+... BM_fit_data Re-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Re-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Re-XO is None, skipping.
#   BigDFT+... BM_fit_data Re-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Re-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Rh-X2O is None, skipping.
#   BigDFT+... BM_fit_data Rh-XO is None, skipping.
#   BigDFT+... BM_fit_data Rh-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Rn-X2O is None, skipping.
#   BigDFT+... BM_fit_data Rn-XO is None, skipping.
#   BigDFT+... BM_fit_data Rn-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Rn-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Ru-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ru-XO is None, skipping.
#   BigDFT+... BM_fit_data Ru-XO2 is None, skipping.
#   BigDFT+... BM_fit_data S-X2O is None, skipping.
#   BigDFT+... BM_fit_data S-XO is None, skipping.
#   BigDFT+... BM_fit_data S-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Sb-X2O is None, skipping.
#   BigDFT+... BM_fit_data Sb-XO is None, skipping.
#   BigDFT+... BM_fit_data Sb-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Sc-X2O is None, skipping.
#   BigDFT+... BM_fit_data Sc-XO is None, skipping.
#   BigDFT+... BM_fit_data Sc-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Se-X2O is None, skipping.
#   BigDFT+... BM_fit_data Se-XO is None, skipping.
#   BigDFT+... BM_fit_data Se-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Si-X2O is None, skipping.
#   BigDFT+... BM_fit_data Si-XO is None, skipping.
#   BigDFT+... BM_fit_data Si-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Sm-X2O is None, skipping.
#   BigDFT+... BM_fit_data Sm-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Sm-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Sm-XO is None, skipping.
#   BigDFT+... BM_fit_data Sm-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Sm-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Sn-X2O is None, skipping.
#   BigDFT+... BM_fit_data Sn-XO is None, skipping.
#   BigDFT+... BM_fit_data Sn-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Sr-X2O is None, skipping.
#   BigDFT+... BM_fit_data Sr-XO is None, skipping.
#   BigDFT+... BM_fit_data Sr-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ta-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ta-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Ta-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Ta-XO is None, skipping.
#   BigDFT+... BM_fit_data Ta-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Ta-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Tb-X2O is None, skipping.
#   BigDFT+... BM_fit_data Tb-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Tb-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Tb-XO is None, skipping.
#   BigDFT+... BM_fit_data Tb-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Tb-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Tc-X2O is None, skipping.
#   BigDFT+... BM_fit_data Tc-XO is None, skipping.
#   BigDFT+... BM_fit_data Tc-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Te-X2O is None, skipping.
#   BigDFT+... BM_fit_data Te-XO is None, skipping.
#   BigDFT+... BM_fit_data Te-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Te-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Ti-X2O is None, skipping.
#   BigDFT+... BM_fit_data Ti-XO is None, skipping.
#   BigDFT+... BM_fit_data Ti-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Tl-X2O is None, skipping.
#   BigDFT+... BM_fit_data Tl-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Tl-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Tl-XO is None, skipping.
#   BigDFT+... BM_fit_data Tl-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Tm-X2O is None, skipping.
#   BigDFT+... BM_fit_data Tm-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Tm-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Tm-XO is None, skipping.
#   BigDFT+... BM_fit_data Tm-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Tm-XO3 is None, skipping.
#   BigDFT+... BM_fit_data V-X2O is None, skipping.
#   BigDFT+... BM_fit_data V-XO is None, skipping.
#   BigDFT+... BM_fit_data V-XO2 is None, skipping.
#   BigDFT+... BM_fit_data W-X2O is None, skipping.
#   BigDFT+... BM_fit_data W-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data W-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data W-XO is None, skipping.
#   BigDFT+... BM_fit_data W-XO2 is None, skipping.
#   BigDFT+... BM_fit_data W-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Xe-X2O is None, skipping.
#   BigDFT+... BM_fit_data Xe-XO is None, skipping.
#   BigDFT+... BM_fit_data Xe-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Y-X2O is None, skipping.
#   BigDFT+... BM_fit_data Y-XO is None, skipping.
#   BigDFT+... BM_fit_data Y-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Yb-X2O is None, skipping.
#   BigDFT+... BM_fit_data Yb-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Yb-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Yb-XO is None, skipping.
#   BigDFT+... BM_fit_data Yb-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Yb-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Zn-X2O is None, skipping.
#   BigDFT+... BM_fit_data Zn-X2O3 is None, skipping.
#   BigDFT+... BM_fit_data Zn-X2O5 is None, skipping.
#   BigDFT+... BM_fit_data Zn-XO is None, skipping.
#   BigDFT+... BM_fit_data Zn-XO2 is None, skipping.
#   BigDFT+... BM_fit_data Zn-XO3 is None, skipping.
#   BigDFT+... BM_fit_data Zr-X2O is None, skipping.
#   BigDFT+... BM_fit_data Zr-XO is None, skipping.
#   BigDFT+... BM_fit_data Zr-XO2 is None, skipping.
#   BigDFT+... eos_data Ag-X2O is None, skipping.
#   BigDFT+... eos_data Ag-XO is None, skipping.
#   BigDFT+... eos_data Ag-XO2 is None, skipping.
#   BigDFT+... eos_data Al-X2O is None, skipping.
#   BigDFT+... eos_data Al-XO is None, skipping.
#   BigDFT+... eos_data Al-XO2 is None, skipping.
#   BigDFT+... eos_data Ar-X2O is None, skipping.
#   BigDFT+... eos_data Ar-XO is None, skipping.
#   BigDFT+... eos_data Ar-XO2 is None, skipping.
#   BigDFT+... eos_data As-X2O is None, skipping.
#   BigDFT+... eos_data As-XO is None, skipping.
#   BigDFT+... eos_data As-XO2 is None, skipping.
#   BigDFT+... eos_data Au-X2O is None, skipping.
#   BigDFT+... eos_data Au-XO is None, skipping.
#   BigDFT+... eos_data Au-XO2 is None, skipping.
#   BigDFT+... eos_data Au-XO3 is None, skipping.
#   BigDFT+... eos_data B-X2O is None, skipping.
#   BigDFT+... eos_data B-XO is None, skipping.
#   BigDFT+... eos_data B-XO2 is None, skipping.
#   BigDFT+... eos_data Ba-X2O is None, skipping.
#   BigDFT+... eos_data Ba-X2O3 is None, skipping.
#   BigDFT+... eos_data Ba-X2O5 is None, skipping.
#   BigDFT+... eos_data Ba-XO is None, skipping.
#   BigDFT+... eos_data Ba-XO2 is None, skipping.
#   BigDFT+... eos_data Be-X2O is None, skipping.
#   BigDFT+... eos_data Be-X2O3 is None, skipping.
#   BigDFT+... eos_data Be-XO is None, skipping.
#   BigDFT+... eos_data Be-XO2 is None, skipping.
#   BigDFT+... eos_data Bi-X2O is None, skipping.
#   BigDFT+... eos_data Bi-XO is None, skipping.
#   BigDFT+... eos_data Bi-XO2 is None, skipping.
#   BigDFT+... eos_data Br-X2O is None, skipping.
#   BigDFT+... eos_data Br-XO is None, skipping.
#   BigDFT+... eos_data Br-XO2 is None, skipping.
#   BigDFT+... eos_data C-X2O is None, skipping.
#   BigDFT+... eos_data C-XO is None, skipping.
#   BigDFT+... eos_data C-XO2 is None, skipping.
#   BigDFT+... eos_data Ca-X2O is None, skipping.
#   BigDFT+... eos_data Ca-XO is None, skipping.
#   BigDFT+... eos_data Ca-XO2 is None, skipping.
#   BigDFT+... eos_data Cd-X2O is None, skipping.
#   BigDFT+... eos_data Cd-XO is None, skipping.
#   BigDFT+... eos_data Cd-XO2 is None, skipping.
#   BigDFT+... eos_data Ce-X2O is None, skipping.
#   BigDFT+... eos_data Ce-X2O3 is None, skipping.
#   BigDFT+... eos_data Ce-X2O5 is None, skipping.
#   BigDFT+... eos_data Ce-XO is None, skipping.
#   BigDFT+... eos_data Ce-XO2 is None, skipping.
#   BigDFT+... eos_data Ce-XO3 is None, skipping.
#   BigDFT+... eos_data Cl-X2O is None, skipping.
#   BigDFT+... eos_data Cl-XO is None, skipping.
#   BigDFT+... eos_data Cl-XO2 is None, skipping.
#   BigDFT+... eos_data Co-X2O is None, skipping.
#   BigDFT+... eos_data Co-X2O3 is None, skipping.
#   BigDFT+... eos_data Co-X2O5 is None, skipping.
#   BigDFT+... eos_data Co-XO is None, skipping.
#   BigDFT+... eos_data Co-XO2 is None, skipping.
#   BigDFT+... eos_data Co-XO3 is None, skipping.
#   BigDFT+... eos_data Cr-X2O is None, skipping.
#   BigDFT+... eos_data Cr-XO is None, skipping.
#   BigDFT+... eos_data Cr-XO2 is None, skipping.
#   BigDFT+... eos_data Cs-X2O is None, skipping.
#   BigDFT+... eos_data Cs-XO is None, skipping.
#   BigDFT+... eos_data Cs-XO2 is None, skipping.
#   BigDFT+... eos_data Cs-XO3 is None, skipping.
#   BigDFT+... eos_data Cu-X2O is None, skipping.
#   BigDFT+... eos_data Cu-X2O5 is None, skipping.
#   BigDFT+... eos_data Cu-XO is None, skipping.
#   BigDFT+... eos_data Cu-XO2 is None, skipping.
#   BigDFT+... eos_data Dy-X2O is None, skipping.
#   BigDFT+... eos_data Dy-X2O3 is None, skipping.
#   BigDFT+... eos_data Dy-X2O5 is None, skipping.
#   BigDFT+... eos_data Dy-XO is None, skipping.
#   BigDFT+... eos_data Dy-XO2 is None, skipping.
#   BigDFT+... eos_data Dy-XO3 is None, skipping.
#   BigDFT+... eos_data Er-X2O is None, skipping.
#   BigDFT+... eos_data Er-X2O3 is None, skipping.
#   BigDFT+... eos_data Er-X2O5 is None, skipping.
#   BigDFT+... eos_data Er-XO is None, skipping.
#   BigDFT+... eos_data Er-XO2 is None, skipping.
#   BigDFT+... eos_data Er-XO3 is None, skipping.
#   BigDFT+... eos_data Eu-X2O is None, skipping.
#   BigDFT+... eos_data Eu-X2O3 is None, skipping.
#   BigDFT+... eos_data Eu-X2O5 is None, skipping.
#   BigDFT+... eos_data Eu-XO is None, skipping.
#   BigDFT+... eos_data Eu-XO2 is None, skipping.
#   BigDFT+... eos_data Eu-XO3 is None, skipping.
#   BigDFT+... eos_data F-X2O is None, skipping.
#   BigDFT+... eos_data F-XO is None, skipping.
#   BigDFT+... eos_data F-XO2 is None, skipping.
#   BigDFT+... eos_data Fe-X2O is None, skipping.
#   BigDFT+... eos_data Fe-X2O5 is None, skipping.
#   BigDFT+... eos_data Fe-XO is None, skipping.
#   BigDFT+... eos_data Fe-XO2 is None, skipping.
#   BigDFT+... eos_data Ga-X2O is None, skipping.
#   BigDFT+... eos_data Ga-XO is None, skipping.
#   BigDFT+... eos_data Ga-XO2 is None, skipping.
#   BigDFT+... eos_data Gd-X2O is None, skipping.
#   BigDFT+... eos_data Gd-X2O3 is None, skipping.
#   BigDFT+... eos_data Gd-X2O5 is None, skipping.
#   BigDFT+... eos_data Gd-XO is None, skipping.
#   BigDFT+... eos_data Gd-XO2 is None, skipping.
#   BigDFT+... eos_data Gd-XO3 is None, skipping.
#   BigDFT+... eos_data Ge-X2O is None, skipping.
#   BigDFT+... eos_data Ge-XO is None, skipping.
#   BigDFT+... eos_data Ge-XO2 is None, skipping.
#   BigDFT+... eos_data H-X2O is None, skipping.
#   BigDFT+... eos_data H-X2O3 is None, skipping.
#   BigDFT+... eos_data H-XO is None, skipping.
#   BigDFT+... eos_data H-XO2 is None, skipping.
#   BigDFT+... eos_data He-X2O is None, skipping.
#   BigDFT+... eos_data He-XO is None, skipping.
#   BigDFT+... eos_data He-XO2 is None, skipping.
#   BigDFT+... eos_data Hf-X2O is None, skipping.
#   BigDFT+... eos_data Hf-XO is None, skipping.
#   BigDFT+... eos_data Hf-XO2 is None, skipping.
#   BigDFT+... eos_data Hg-X2O is None, skipping.
#   BigDFT+... eos_data Hg-XO is None, skipping.
#   BigDFT+... eos_data Hg-XO2 is None, skipping.
#   BigDFT+... eos_data Ho-X2O is None, skipping.
#   BigDFT+... eos_data Ho-X2O3 is None, skipping.
#   BigDFT+... eos_data Ho-X2O5 is None, skipping.
#   BigDFT+... eos_data Ho-XO is None, skipping.
#   BigDFT+... eos_data Ho-XO2 is None, skipping.
#   BigDFT+... eos_data Ho-XO3 is None, skipping.
#   BigDFT+... eos_data I-X2O is None, skipping.
#   BigDFT+... eos_data I-XO is None, skipping.
#   BigDFT+... eos_data I-XO2 is None, skipping.
#   BigDFT+... eos_data I-XO3 is None, skipping.
#   BigDFT+... eos_data In-X2O is None, skipping.
#   BigDFT+... eos_data In-XO is None, skipping.
#   BigDFT+... eos_data In-XO2 is None, skipping.
#   BigDFT+... eos_data Ir-X2O is None, skipping.
#   BigDFT+... eos_data Ir-X2O3 is None, skipping.
#   BigDFT+... eos_data Ir-XO is None, skipping.
#   BigDFT+... eos_data Ir-XO2 is None, skipping.
#   BigDFT+... eos_data Ir-XO3 is None, skipping.
#   BigDFT+... eos_data K-X2O is None, skipping.
#   BigDFT+... eos_data K-XO is None, skipping.
#   BigDFT+... eos_data K-XO2 is None, skipping.
#   BigDFT+... eos_data K-XO3 is None, skipping.
#   BigDFT+... eos_data Kr-X2O is None, skipping.
#   BigDFT+... eos_data Kr-XO is None, skipping.
#   BigDFT+... eos_data Kr-XO2 is None, skipping.
#   BigDFT+... eos_data La-X2O is None, skipping.
#   BigDFT+... eos_data La-X2O3 is None, skipping.
#   BigDFT+... eos_data La-X2O5 is None, skipping.
#   BigDFT+... eos_data La-XO is None, skipping.
#   BigDFT+... eos_data La-XO2 is None, skipping.
#   BigDFT+... eos_data Li-X2O is None, skipping.
#   BigDFT+... eos_data Li-X2O3 is None, skipping.
#   BigDFT+... eos_data Li-XO is None, skipping.
#   BigDFT+... eos_data Li-XO2 is None, skipping.
#   BigDFT+... eos_data Li-XO3 is None, skipping.
#   BigDFT+... eos_data Lu-X2O is None, skipping.
#   BigDFT+... eos_data Lu-X2O3 is None, skipping.
#   BigDFT+... eos_data Lu-X2O5 is None, skipping.
#   BigDFT+... eos_data Lu-XO is None, skipping.
#   BigDFT+... eos_data Lu-XO2 is None, skipping.
#   BigDFT+... eos_data Lu-XO3 is None, skipping.
#   BigDFT+... eos_data Mg-X2O is None, skipping.
#   BigDFT+... eos_data Mg-XO is None, skipping.
#   BigDFT+... eos_data Mg-XO2 is None, skipping.
#   BigDFT+... eos_data Mn-X2O is None, skipping.
#   BigDFT+... eos_data Mn-XO is None, skipping.
#   BigDFT+... eos_data Mn-XO2 is None, skipping.
#   BigDFT+... eos_data Mo-X2O is None, skipping.
#   BigDFT+... eos_data Mo-XO is None, skipping.
#   BigDFT+... eos_data Mo-XO2 is None, skipping.
#   BigDFT+... eos_data N-X2O is None, skipping.
#   BigDFT+... eos_data N-XO is None, skipping.
#   BigDFT+... eos_data N-XO2 is None, skipping.
#   BigDFT+... eos_data Na-X2O is None, skipping.
#   BigDFT+... eos_data Na-X2O3 is None, skipping.
#   BigDFT+... eos_data Na-X2O5 is None, skipping.
#   BigDFT+... eos_data Na-XO is None, skipping.
#   BigDFT+... eos_data Na-XO2 is None, skipping.
#   BigDFT+... eos_data Na-XO3 is None, skipping.
#   BigDFT+... eos_data Nb-X2O is None, skipping.
#   BigDFT+... eos_data Nb-XO is None, skipping.
#   BigDFT+... eos_data Nb-XO2 is None, skipping.
#   BigDFT+... eos_data Nd-X2O is None, skipping.
#   BigDFT+... eos_data Nd-X2O3 is None, skipping.
#   BigDFT+... eos_data Nd-X2O5 is None, skipping.
#   BigDFT+... eos_data Nd-XO is None, skipping.
#   BigDFT+... eos_data Nd-XO2 is None, skipping.
#   BigDFT+... eos_data Nd-XO3 is None, skipping.
#   BigDFT+... eos_data Ne-X2O is None, skipping.
#   BigDFT+... eos_data Ne-X2O3 is None, skipping.
#   BigDFT+... eos_data Ne-X2O5 is None, skipping.
#   BigDFT+... eos_data Ne-XO is None, skipping.
#   BigDFT+... eos_data Ne-XO2 is None, skipping.
#   BigDFT+... eos_data Ni-X2O is None, skipping.
#   BigDFT+... eos_data Ni-X2O3 is None, skipping.
#   BigDFT+... eos_data Ni-X2O5 is None, skipping.
#   BigDFT+... eos_data Ni-XO is None, skipping.
#   BigDFT+... eos_data Ni-XO2 is None, skipping.
#   BigDFT+... eos_data Ni-XO3 is None, skipping.
#   BigDFT+... eos_data O-X2O is None, skipping.
#   BigDFT+... eos_data O-X2O3 is None, skipping.
#   BigDFT+... eos_data O-X2O5 is None, skipping.
#   BigDFT+... eos_data O-XO is None, skipping.
#   BigDFT+... eos_data O-XO2 is None, skipping.
#   BigDFT+... eos_data Os-X2O is None, skipping.
#   BigDFT+... eos_data Os-X2O3 is None, skipping.
#   BigDFT+... eos_data Os-XO is None, skipping.
#   BigDFT+... eos_data Os-XO2 is None, skipping.
#   BigDFT+... eos_data Os-XO3 is None, skipping.
#   BigDFT+... eos_data P-X2O is None, skipping.
#   BigDFT+... eos_data P-XO is None, skipping.
#   BigDFT+... eos_data P-XO2 is None, skipping.
#   BigDFT+... eos_data Pb-X2O is None, skipping.
#   BigDFT+... eos_data Pb-XO is None, skipping.
#   BigDFT+... eos_data Pb-XO2 is None, skipping.
#   BigDFT+... eos_data Pd-X2O is None, skipping.
#   BigDFT+... eos_data Pd-XO is None, skipping.
#   BigDFT+... eos_data Pd-XO2 is None, skipping.
#   BigDFT+... eos_data Pm-X2O is None, skipping.
#   BigDFT+... eos_data Pm-X2O3 is None, skipping.
#   BigDFT+... eos_data Pm-X2O5 is None, skipping.
#   BigDFT+... eos_data Pm-XO is None, skipping.
#   BigDFT+... eos_data Pm-XO2 is None, skipping.
#   BigDFT+... eos_data Pm-XO3 is None, skipping.
#   BigDFT+... eos_data Po-X2O is None, skipping.
#   BigDFT+... eos_data Po-XO is None, skipping.
#   BigDFT+... eos_data Po-XO2 is None, skipping.
#   BigDFT+... eos_data Po-XO3 is None, skipping.
#   BigDFT+... eos_data Pr-X2O is None, skipping.
#   BigDFT+... eos_data Pr-X2O3 is None, skipping.
#   BigDFT+... eos_data Pr-X2O5 is None, skipping.
#   BigDFT+... eos_data Pr-XO is None, skipping.
#   BigDFT+... eos_data Pr-XO2 is None, skipping.
#   BigDFT+... eos_data Pr-XO3 is None, skipping.
#   BigDFT+... eos_data Pt-X2O is None, skipping.
#   BigDFT+... eos_data Pt-XO is None, skipping.
#   BigDFT+... eos_data Pt-XO2 is None, skipping.
#   BigDFT+... eos_data Pt-XO3 is None, skipping.
#   BigDFT+... eos_data Rb-X2O is None, skipping.
#   BigDFT+... eos_data Rb-XO is None, skipping.
#   BigDFT+... eos_data Rb-XO2 is None, skipping.
#   BigDFT+... eos_data Rb-XO3 is None, skipping.
#   BigDFT+... eos_data Re-X2O is None, skipping.
#   BigDFT+... eos_data Re-X2O3 is None, skipping.
#   BigDFT+... eos_data Re-X2O5 is None, skipping.
#   BigDFT+... eos_data Re-XO is None, skipping.
#   BigDFT+... eos_data Re-XO2 is None, skipping.
#   BigDFT+... eos_data Re-XO3 is None, skipping.
#   BigDFT+... eos_data Rh-X2O is None, skipping.
#   BigDFT+... eos_data Rh-XO is None, skipping.
#   BigDFT+... eos_data Rh-XO2 is None, skipping.
#   BigDFT+... eos_data Rn-X2O is None, skipping.
#   BigDFT+... eos_data Rn-XO is None, skipping.
#   BigDFT+... eos_data Rn-XO2 is None, skipping.
#   BigDFT+... eos_data Rn-XO3 is None, skipping.
#   BigDFT+... eos_data Ru-X2O is None, skipping.
#   BigDFT+... eos_data Ru-XO is None, skipping.
#   BigDFT+... eos_data Ru-XO2 is None, skipping.
#   BigDFT+... eos_data S-X2O is None, skipping.
#   BigDFT+... eos_data S-XO is None, skipping.
#   BigDFT+... eos_data S-XO2 is None, skipping.
#   BigDFT+... eos_data Sb-X2O is None, skipping.
#   BigDFT+... eos_data Sb-XO is None, skipping.
#   BigDFT+... eos_data Sb-XO2 is None, skipping.
#   BigDFT+... eos_data Sc-X2O is None, skipping.
#   BigDFT+... eos_data Sc-XO is None, skipping.
#   BigDFT+... eos_data Sc-XO2 is None, skipping.
#   BigDFT+... eos_data Se-X2O is None, skipping.
#   BigDFT+... eos_data Se-XO is None, skipping.
#   BigDFT+... eos_data Se-XO2 is None, skipping.
#   BigDFT+... eos_data Si-X2O is None, skipping.
#   BigDFT+... eos_data Si-XO is None, skipping.
#   BigDFT+... eos_data Si-XO2 is None, skipping.
#   BigDFT+... eos_data Sm-X2O is None, skipping.
#   BigDFT+... eos_data Sm-X2O3 is None, skipping.
#   BigDFT+... eos_data Sm-X2O5 is None, skipping.
#   BigDFT+... eos_data Sm-XO is None, skipping.
#   BigDFT+... eos_data Sm-XO2 is None, skipping.
#   BigDFT+... eos_data Sm-XO3 is None, skipping.
#   BigDFT+... eos_data Sn-X2O is None, skipping.
#   BigDFT+... eos_data Sn-XO is None, skipping.
#   BigDFT+... eos_data Sn-XO2 is None, skipping.
#   BigDFT+... eos_data Sr-X2O is None, skipping.
#   BigDFT+... eos_data Sr-XO is None, skipping.
#   BigDFT+... eos_data Sr-XO2 is None, skipping.
#   BigDFT+... eos_data Ta-X2O is None, skipping.
#   BigDFT+... eos_data Ta-X2O3 is None, skipping.
#   BigDFT+... eos_data Ta-X2O5 is None, skipping.
#   BigDFT+... eos_data Ta-XO is None, skipping.
#   BigDFT+... eos_data Ta-XO2 is None, skipping.
#   BigDFT+... eos_data Ta-XO3 is None, skipping.
#   BigDFT+... eos_data Tb-X2O is None, skipping.
#   BigDFT+... eos_data Tb-X2O3 is None, skipping.
#   BigDFT+... eos_data Tb-X2O5 is None, skipping.
#   BigDFT+... eos_data Tb-XO is None, skipping.
#   BigDFT+... eos_data Tb-XO2 is None, skipping.
#   BigDFT+... eos_data Tb-XO3 is None, skipping.
#   BigDFT+... eos_data Tc-X2O is None, skipping.
#   BigDFT+... eos_data Tc-XO is None, skipping.
#   BigDFT+... eos_data Tc-XO2 is None, skipping.
#   BigDFT+... eos_data Te-X2O is None, skipping.
#   BigDFT+... eos_data Te-XO is None, skipping.
#   BigDFT+... eos_data Te-XO2 is None, skipping.
#   BigDFT+... eos_data Te-XO3 is None, skipping.
#   BigDFT+... eos_data Ti-X2O is None, skipping.
#   BigDFT+... eos_data Ti-XO is None, skipping.
#   BigDFT+... eos_data Ti-XO2 is None, skipping.
#   BigDFT+... eos_data Tl-X2O is None, skipping.
#   BigDFT+... eos_data Tl-X2O3 is None, skipping.
#   BigDFT+... eos_data Tl-X2O5 is None, skipping.
#   BigDFT+... eos_data Tl-XO is None, skipping.
#   BigDFT+... eos_data Tl-XO2 is None, skipping.
#   BigDFT+... eos_data Tm-X2O is None, skipping.
#   BigDFT+... eos_data Tm-X2O3 is None, skipping.
#   BigDFT+... eos_data Tm-X2O5 is None, skipping.
#   BigDFT+... eos_data Tm-XO is None, skipping.
#   BigDFT+... eos_data Tm-XO2 is None, skipping.
#   BigDFT+... eos_data Tm-XO3 is None, skipping.
#   BigDFT+... eos_data V-X2O is None, skipping.
#   BigDFT+... eos_data V-XO is None, skipping.
#   BigDFT+... eos_data V-XO2 is None, skipping.
#   BigDFT+... eos_data W-X2O is None, skipping.
#   BigDFT+... eos_data W-X2O3 is None, skipping.
#   BigDFT+... eos_data W-X2O5 is None, skipping.
#   BigDFT+... eos_data W-XO is None, skipping.
#   BigDFT+... eos_data W-XO2 is None, skipping.
#   BigDFT+... eos_data W-XO3 is None, skipping.
#   BigDFT+... eos_data Xe-X2O is None, skipping.
#   BigDFT+... eos_data Xe-XO is None, skipping.
#   BigDFT+... eos_data Xe-XO2 is None, skipping.
#   BigDFT+... eos_data Y-X2O is None, skipping.
#   BigDFT+... eos_data Y-XO is None, skipping.
#   BigDFT+... eos_data Y-XO2 is None, skipping.
#   BigDFT+... eos_data Yb-X2O is None, skipping.
#   BigDFT+... eos_data Yb-X2O3 is None, skipping.
#   BigDFT+... eos_data Yb-X2O5 is None, skipping.
#   BigDFT+... eos_data Yb-XO is None, skipping.
#   BigDFT+... eos_data Yb-XO2 is None, skipping.
#   BigDFT+... eos_data Yb-XO3 is None, skipping.
#   BigDFT+... eos_data Zn-X2O is None, skipping.
#   BigDFT+... eos_data Zn-X2O3 is None, skipping.
#   BigDFT+... eos_data Zn-X2O5 is None, skipping.
#   BigDFT+... eos_data Zn-XO is None, skipping.
#   BigDFT+... eos_data Zn-XO2 is None, skipping.
#   BigDFT+... eos_data Zn-XO3 is None, skipping.
#   BigDFT+... eos_data Zr-X2O is None, skipping.
#   BigDFT+... eos_data Zr-XO is None, skipping.
#   BigDFT+... eos_data Zr-XO2 is None, skipping.
# Loading results-unaries-verification-PBE-v1-cp2k_TZV2P.json
#   CP2K+GTH+TZV2P BM_fit_data Na-X/FCC is None, skipping.
# Loading results-oxides-verification-PBE-v1-cp2k_TZV2P.json
# Loading results-unaries-verification-PBE-v1-fleur.json
# Loading results-oxides-verification-PBE-v1-fleur.json
# Loading results-unaries-verification-PBE-v1-gpaw.json
# Loading results-oxides-verification-PBE-v1-gpaw.json
# Loading results-unaries-verification-PBE-v1-castep.json
# Loading results-oxides-verification-PBE-v1-castep.json
# Loading results-unaries-verification-PBE-v1-quantum_espresso.json
# Loading results-oxides-verification-PBE-v1-quantum_espresso.json
# Loading results-unaries-verification-PBE-v1-siesta.json
#   SIESTA+PseudoDojo+OptDiamond BM_fit_data Hg-X/FCC is None, skipping.
# Loading results-oxides-verification-PBE-v1-siesta.json
#   SIESTA+PseudoDojo+OptDiamond BM_fit_data Rb-XO3 is None, skipping.
# Loading results-unaries-verification-PBE-v1-cp2k-sirius.json
# Loading results-oxides-verification-PBE-v1-cp2k-sirius.json
# Loading results-unaries-verification-PBE-v1-vasp.json
# Loading results-oxides-verification-PBE-v1-vasp.json
# Loading results-unaries-verification-PBE-v1-wien2k-dk_0.06.json
# Loading results-oxides-verification-PBE-v1-wien2k-dk_0.06.json

# %%
final_data = {
    "metadata": meta,
    "data": data
}

fname = "data.json"
with open(fname, 'w') as f:
    #json.dump(final_data, f)
    json.dump(final_data, f, indent=2)
    print(f"Wrote {fname}!")
# Out:
# Wrote data.json!
